# %%
import tensorflow as tf

from tensorflow.keras import Model, models,layers 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.backend import batch_normalization 
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical


import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import re
from tqdm import tqdm

# %%
def custom_model():
    model = Sequential()
    model.add(MaxPooling2D((4,4), strides=None, padding='valid', input_shape=(1394, 1162, 4)))
    model.add(MaxPooling2D((2,2), strides=None, padding='valid'))
    model.add(Conv2D(64, (7,7), padding='valid', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(128, (5,5), padding='valid', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(MaxPooling2D((3,3), strides=None, padding='valid'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(MaxPooling2D((2,2), strides=None, padding='valid'))
    model.add(MaxPooling2D((2,2), strides=None, padding='valid'))
    model.add(Flatten())
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform')) 
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))
    #Last layer should one unit per output class. If classifying between six dates
    #then six output units.
    x = model.add(Dense(2, activation='softmax', kernel_initializer='he_uniform'))
    
    opt = Adam(lr=0.001, beta_1=0.9, beta_2 = 0.999)
    model.compile(optimizer=opt, loss='KLDivergence', metrics=['accuracy', 'Precision'])
    
    return model

# %%
model = custom_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  max_pooling2d (MaxPooling2D  (None, 348, 290, 4)      0
#  )
#
#  max_pooling2d_1 (MaxPooling  (None, 174, 145, 4)      0
#  2D)
#
#  conv2d (Conv2D)             (None, 168, 139, 64)      12608
#
#  batch_normalization (BatchN  (None, 168, 139, 64)     256
#  ormalization)
#
#  dropout (Dropout)           (None, 168, 139, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 164, 135, 128)     204928
#
#  batch_normalization_1 (Batc  (None, 164, 135, 128)    512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 164, 135, 128)     0
#
#  max_pooling2d_2 (MaxPooling  (None, 54, 45, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 54, 45, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 54, 45, 256)      1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 54, 45, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 54, 45, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 54, 45, 256)      1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 54, 45, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 54, 45, 512)       1180160
#
#  batch_normalization_4 (Batc  (None, 54, 45, 512)      2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 54, 45, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 54, 45, 512)       2359808
#
#  batch_normalization_5 (Batc  (None, 54, 45, 512)      2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 54, 45, 512)       0
#
#  conv2d_6 (Conv2D)           (None, 54, 45, 512)       2359808
#
#  batch_normalization_6 (Batc  (None, 54, 45, 512)      2048
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 54, 45, 512)       0
#
#  conv2d_7 (Conv2D)           (None, 54, 45, 512)       2359808
#
#  batch_normalization_7 (Batc  (None, 54, 45, 512)      2048
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 54, 45, 512)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 27, 22, 512)      0
#  2D)
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 11, 512)      0
#  2D)
#
#  flatten (Flatten)           (None, 73216)             0
#
#  dense (Dense)               (None, 64)                4685888
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_9 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 14,061,794
# Trainable params: 14,056,098
# Non-trainable params: 5,696
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
files = os.listdir('/content/drive/MyDrive/Matrices_2')

train_files = files[:396]  # here
test_files = files[396:]

def make_inputs(inputs):
    train_x = []
    train_y = []
    
    date_list = ['2022-March','2021-May','2021-March','2020-December', '12:17:20', '2:17:20', '3:8:22', 
                 '5:22:21', '7:9:20']
    for file in inputs:
        #Got error when labels went from 1-4 instead of 0-3
        if file[3:-4] == '2022-March' or file[2:-4] == '2022-March' or file[4:-4] == '2022-March':
            train_y.append(0)
        if file[3:-4] == '2021-May' or file[2:-4] == '2021-May' or file[4:-4] == '2021-May':
            train_y.append(0)
        if file[3:-4] == '2021-March' or file[2:-4] == '2021-March' or file[4:-4] == '2021-March':
            train_y.append(1)
        if file[3:-4] == '2020-December' or file[2:-4] == '2020-December' or file[4:-4] == '2020-December':
            train_y.append(1)
        if file[3:-4] == '12:17:20' or file[2:-4] == '12:17:20' or file[4:-4] == '12:17:20':
            train_y.append(1)
        if file[3:-4] == '3:8:22' or file[2:-4] == '3:8:22' or file[4:-4] == '3:8:22':
            train_y.append(0)
        if file[3:-4] == '5:22:21' or file[2:-4] == '5:22:21' or file[4:-4] == '5:22:21':
            train_y.append(0)
        if file[3:-4] == '7:9:20' or file[2:-4] == '7:9:20' or file[4:-4] == '7:9:20':
            train_y.append(1)
        
        if file[3:-4] in date_list or file[2:-4] in date_list or file[4:-4] in date_list:
            #print(file)
            train_x.append(cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{file}'), (1162, 1394)))

    train_x = np.asarray(train_x)
    train_y = np.asarray(train_y).reshape(len(train_y),1)
    train_y = to_categorical(train_y)
    
    return train_x, train_y

# %%
train_x, train_y = make_inputs(train_files)
test_x, test_y = make_inputs(test_files)

# %%
print(train_x.shape)
print(train_y.shape)
print('----')
print(test_x.shape)
print(test_y.shape)
# Out:
# (395, 1394, 1162, 4)
# (395, 2)
# ----
# (20, 1394, 1162, 4)
# (20, 2)

# %%
tf.config.run_functions_eagerly(True)

# %%
#early_stopping=tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0,
#                              patience=3, verbose=0, mode='auto',
#baseline=None, restore_best_weights=True)
#result = model.fit(train_x, train_y, epochs=20, batch_size=10,validation_data=(test_x, test_y), callbacks = [early_stopping])
result1 = model.fit(train_x, train_y, epochs=50, batch_size=10,validation_data=(test_x, test_y))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# Epoch 1/50
# 40/40 [==============================] - 11s 219ms/step - loss: 1.4766 - accuracy: 0.5570 - precision: 0.5570 - val_loss: 0.8889 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 2/50
# 40/40 [==============================] - 8s 204ms/step - loss: 1.3420 - accuracy: 0.5620 - precision: 0.5620 - val_loss: 1.6154 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 3/50
# 40/40 [==============================] - 8s 205ms/step - loss: 1.2871 - accuracy: 0.5620 - precision: 0.5620 - val_loss: 2.3482 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 4/50
# 40/40 [==============================] - 8s 204ms/step - loss: 1.3215 - accuracy: 0.5519 - precision: 0.5519 - val_loss: 1.9801 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 5/50
# 40/40 [==============================] - 8s 205ms/step - loss: 1.0442 - accuracy: 0.5772 - precision: 0.5772 - val_loss: 2.2241 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 6/50
# 40/40 [==============================] - 8s 206ms/step - loss: 1.1611 - accuracy: 0.5620 - precision: 0.5620 - val_loss: 4.5071 - val_accuracy: 0.6000 - val_precision: 0.6000
# Epoch 7/50
# 40/40 [==============================] - 8s 205ms/step - loss: 1.0205 - accuracy: 0.5696 - precision: 0.5696 - val_loss: 2.7716 - val_accuracy: 0.2000 - val_precision: 0.2000
# Epoch 8/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.8779 - accuracy: 0.5924 - precision: 0.5924 - val_loss: 7.1759 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 9/50
# 40/40 [==============================] - 8s 210ms/step - loss: 0.8140 - accuracy: 0.6152 - precision: 0.6152 - val_loss: 8.0592 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 10/50
# 40/40 [==============================] - 8s 206ms/step - loss: 0.9313 - accuracy: 0.5899 - precision: 0.5899 - val_loss: 7.8582 - val_accuracy: 0.4500 - val_precision: 0.4500
# Epoch 11/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.7574 - accuracy: 0.6278 - precision: 0.6278 - val_loss: 8.7001 - val_accuracy: 0.4500 - val_precision: 0.4500
# Epoch 12/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.7279 - accuracy: 0.6177 - precision: 0.6177 - val_loss: 8.1046 - val_accuracy: 0.4000 - val_precision: 0.4000
# Epoch 13/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.6905 - accuracy: 0.6557 - precision: 0.6557 - val_loss: 8.4274 - val_accuracy: 0.4500 - val_precision: 0.4500
# Epoch 14/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.7485 - accuracy: 0.6582 - precision: 0.6582 - val_loss: 8.0590 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 15/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.7354 - accuracy: 0.6608 - precision: 0.6608 - val_loss: 7.2541 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 16/50
# 40/40 [==============================] - 8s 206ms/step - loss: 0.7064 - accuracy: 0.6101 - precision: 0.6101 - val_loss: 7.7090 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 17/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.6205 - accuracy: 0.7089 - precision: 0.7089 - val_loss: 7.0254 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 18/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.5854 - accuracy: 0.6987 - precision: 0.6987 - val_loss: 6.7752 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 19/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.6095 - accuracy: 0.6684 - precision: 0.6684 - val_loss: 6.5183 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 20/50
# 40/40 [==============================] - 8s 207ms/step - loss: 0.6532 - accuracy: 0.6430 - precision: 0.6430 - val_loss: 4.4997 - val_accuracy: 0.6500 - val_precision: 0.6500
# Epoch 21/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.6231 - accuracy: 0.6835 - precision: 0.6835 - val_loss: 2.8390 - val_accuracy: 0.7500 - val_precision: 0.7500
# Epoch 22/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.5739 - accuracy: 0.7013 - precision: 0.7013 - val_loss: 2.0701 - val_accuracy: 0.7500 - val_precision: 0.7500
# Epoch 23/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5734 - accuracy: 0.7266 - precision: 0.7266 - val_loss: 2.5326 - val_accuracy: 0.8000 - val_precision: 0.8000
# Epoch 24/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.5495 - accuracy: 0.7139 - precision: 0.7139 - val_loss: 5.6448 - val_accuracy: 0.6500 - val_precision: 0.6500
# Epoch 25/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5476 - accuracy: 0.7620 - precision: 0.7620 - val_loss: 3.6029 - val_accuracy: 0.6500 - val_precision: 0.6500
# Epoch 26/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.5580 - accuracy: 0.7165 - precision: 0.7165 - val_loss: 3.2685 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 27/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5498 - accuracy: 0.7241 - precision: 0.7241 - val_loss: 3.3185 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 28/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5534 - accuracy: 0.7266 - precision: 0.7266 - val_loss: 8.3970 - val_accuracy: 0.3500 - val_precision: 0.3500
# Epoch 29/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5991 - accuracy: 0.7190 - precision: 0.7190 - val_loss: 1.9333 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 30/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5755 - accuracy: 0.7367 - precision: 0.7367 - val_loss: 0.6040 - val_accuracy: 0.8000 - val_precision: 0.8000
# Epoch 31/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5285 - accuracy: 0.7367 - precision: 0.7367 - val_loss: 1.2825 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 32/50
# 40/40 [==============================] - 8s 206ms/step - loss: 0.4821 - accuracy: 0.7848 - precision: 0.7848 - val_loss: 1.2707 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 33/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.4710 - accuracy: 0.7975 - precision: 0.7975 - val_loss: 6.1244 - val_accuracy: 0.3500 - val_precision: 0.3500
# Epoch 34/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.4580 - accuracy: 0.8025 - precision: 0.8025 - val_loss: 3.0259 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 35/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4851 - accuracy: 0.7873 - precision: 0.7873 - val_loss: 1.9177 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 36/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4584 - accuracy: 0.7975 - precision: 0.7975 - val_loss: 1.7928 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 37/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.4576 - accuracy: 0.7975 - precision: 0.7975 - val_loss: 2.1340 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 38/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.4807 - accuracy: 0.8051 - precision: 0.8051 - val_loss: 1.8071 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 39/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4630 - accuracy: 0.8127 - precision: 0.8127 - val_loss: 1.9478 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 40/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.5187 - accuracy: 0.7266 - precision: 0.7266 - val_loss: 1.7795 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 41/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4796 - accuracy: 0.8025 - precision: 0.8025 - val_loss: 0.7337 - val_accuracy: 0.8000 - val_precision: 0.8000
# Epoch 42/50
# 40/40 [==============================] - 8s 206ms/step - loss: 0.4390 - accuracy: 0.8101 - precision: 0.8101 - val_loss: 2.0555 - val_accuracy: 0.6000 - val_precision: 0.6000
# Epoch 43/50
# 40/40 [==============================] - 8s 207ms/step - loss: 0.3991 - accuracy: 0.8405 - precision: 0.8405 - val_loss: 1.9252 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 44/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4170 - accuracy: 0.8304 - precision: 0.8304 - val_loss: 2.3742 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 45/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.3971 - accuracy: 0.8354 - precision: 0.8354 - val_loss: 1.8646 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 46/50
# 40/40 [==============================] - 8s 204ms/step - loss: 0.4295 - accuracy: 0.8152 - precision: 0.8152 - val_loss: 2.4411 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 47/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.4707 - accuracy: 0.7975 - precision: 0.7975 - val_loss: 3.1004 - val_accuracy: 0.6000 - val_precision: 0.6000
# Epoch 48/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.3885 - accuracy: 0.8177 - precision: 0.8177 - val_loss: 2.1514 - val_accuracy: 0.6000 - val_precision: 0.6000
# Epoch 49/50
# 40/40 [==============================] - 8s 205ms/step - loss: 0.4133 - accuracy: 0.8278 - precision: 0.8278 - val_loss: 2.6476 - val_accuracy: 0.7000 - val_precision: 0.7000
# Epoch 50/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.4476 - accuracy: 0.8203 - precision: 0.8203 - val_loss: 3.3571 - val_accuracy: 0.5500 - val_precision: 0.5500

# %%
precision = result1.history['precision']
loss = result1.history['loss']
accuracy = result1.history['accuracy']
val_precision = result1.history['val_precision']
val_loss = result1.history['val_loss']
val_accuracy = result1.history['val_accuracy']
epochs = range(len(accuracy))

plt.plot(epochs, precision, 'g', label='Training Precision')
plt.plot(epochs, val_precision, 'r', label='Validation Precision')
plt.title('Train vs Val: Precision')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Train vs Val: Loss')
plt.legend()
plt.figure()
plt.plot(epochs, accuracy, 'g', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Train vs Val: Accuracy')
plt.legend()
plt.figure()
plt.show()

# %%
print(len(files))
#print(len(train_x))
#print(len(test_x))
processed_files = {}
for file_name in files:
  file = file_name[2:-4]

  if file[0] == '-':
    file = file[1:]
  if file[0] == ' ':
    file = file[1:]
  if file[1] == '-':
    file = file[2:]
  processed_files[file_name] = file
print(len(processed_files.values()))
# Out:
# 417
# 417

# %%
count_dict = {}
for file in files:
  count_dict[re.split(' |\-', file)[0]] = []

for file in files:
  key = re.split(' |\-', file)[0]
  count_dict[key].append(file)

# %%
train_dict = {}
test_dict = {}
for key in count_dict.keys():
  if len(count_dict[key]) == 4:
    val = count_dict[key]
    train_dict[key] = val
  if len(count_dict[key]) == 2:
    val = count_dict[key]
    test_dict[key] = val
print(len(count_dict.keys()))
print(len(train_dict.keys()))
print(len(test_dict.keys()))
# Out:
# 111
# 98
# 12

# %%
counter = 0
output_array = []
for key in train_dict.keys():
  val = list(train_dict[key])
  img1 = cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{val[0]}'), (1162, 1394))
  img2 = cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{val[1]}'), (1162, 1394))
  diff = img1 - img2
  diff = diff + np.array([0,0,0,255])
  plt.imshow(diff)
  plt.show()
  print(diff.shape)
  plt.imshow(img1)
  plt.show()
  plt.imshow(img2)
  plt.show()
  break
# Out:
# (1394, 1162, 4)

# %%
diff.shape
# Out:
# (1394, 1162, 4)

# %%
hsv_color1 = np.asarray([0,0,0,255])   # white!
hsv_color2 = np.asarray([138,43,226,255])   # yellow! note the order

output = cv2.inRange(diff, hsv_color1, hsv_color2)
plt.imshow(output, cmap='gray')   # this colormap will display in black / white
plt.show()

# %%
print(output.shape)
#plt.imshow(np.multiply(output, img1))
plt.imshow(img1[:,:,:])
plt.show()
# Out:
# (1394, 1162)

# %%
for i in range(output.shape[0]):
    for j in range(output.shape[1]):
        if output[i][j] == 0:
            img1[i][j] = [0,0,0,0]
plt.imshow(img1)
plt.show()

# %%
def make_inputs_mask(input_dict):
  output_array = []
  output_labels = []
  for key in tqdm(input_dict.keys()):
    value = list(input_dict[key])
    img1 = cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{value[0]}'), (1162, 1394))
    img2 = cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{value[1]}'), (1162, 1394))
    diff = img1 - img2
    diff = diff + np.array([0,0,0,255])

    hsv_color1 = np.asarray([0,0,0,255])   # white!
    hsv_color2 = np.asarray([138,43,226,255])   # yellow! note the order

    output = cv2.inRange(diff, hsv_color1, hsv_color2)

    for val in value:
      img = cv2.resize(np.load(f'/content/drive/MyDrive/Matrices_2/{val}'), (1162, 1394))
      foo = output/255
      test = np.repeat(foo[:,:,np.newaxis], 4,axis=2)
      img = np.multiply(test, img)
      output_array.append(img)
      if '2020' in val:
        output_labels.append(1)
      elif ':20' in val:
        output_labels.append(1)
      else:
        output_labels.append(0)

  output_array = np.asarray(output_array)
  output_labels = np.asarray(output_labels).reshape(len(output_labels),1)
  output_labels = to_categorical(output_labels)
    
  return output_array, output_labels

# %%
mask_train_x, mask_train_y = make_inputs_mask(train_dict)
mask_test_x, mask_test_y = make_inputs_mask(test_dict)
# Out:
# 100%|██████████| 98/98 [00:35<00:00,  2.75it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.72it/s]

# %%
result = model.fit(mask_train_x, mask_train_y, epochs=50, batch_size=10,validation_data=(mask_test_x, mask_test_y))
# Out:
# Epoch 1/50
# 40/40 [==============================] - 25s 274ms/step - loss: 1.6050 - accuracy: 0.4923 - precision: 0.4923 - val_loss: 1.2790 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 2/50
# 40/40 [==============================] - 8s 191ms/step - loss: 1.5508 - accuracy: 0.4974 - precision: 0.4974 - val_loss: 2.8303 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 3/50
# 40/40 [==============================] - 8s 191ms/step - loss: 1.4101 - accuracy: 0.4745 - precision: 0.4745 - val_loss: 5.2075 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 4/50
# 40/40 [==============================] - 8s 192ms/step - loss: 1.2033 - accuracy: 0.5944 - precision: 0.5944 - val_loss: 3.2979 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 5/50
# 40/40 [==============================] - 8s 190ms/step - loss: 1.2800 - accuracy: 0.5179 - precision: 0.5179 - val_loss: 4.9400 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 6/50
# 40/40 [==============================] - 8s 190ms/step - loss: 1.1394 - accuracy: 0.5179 - precision: 0.5179 - val_loss: 6.3175 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 7/50
# 40/40 [==============================] - 8s 190ms/step - loss: 1.0970 - accuracy: 0.5102 - precision: 0.5102 - val_loss: 6.2238 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 8/50
# 40/40 [==============================] - 8s 192ms/step - loss: 1.0824 - accuracy: 0.5383 - precision: 0.5383 - val_loss: 7.3875 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 9/50
# 40/40 [==============================] - 8s 190ms/step - loss: 1.0601 - accuracy: 0.5128 - precision: 0.5128 - val_loss: 7.3875 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 10/50
# 40/40 [==============================] - 8s 189ms/step - loss: 1.0510 - accuracy: 0.4796 - precision: 0.4796 - val_loss: 7.3875 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 11/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.9985 - accuracy: 0.4898 - precision: 0.4898 - val_loss: 6.8493 - val_accuracy: 0.4583 - val_precision: 0.4583
# Epoch 12/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.8733 - accuracy: 0.5510 - precision: 0.5510 - val_loss: 4.1586 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 13/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.8080 - accuracy: 0.5740 - precision: 0.5740 - val_loss: 3.2484 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 14/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.8617 - accuracy: 0.5332 - precision: 0.5332 - val_loss: 2.4164 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 15/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.7723 - accuracy: 0.5969 - precision: 0.5969 - val_loss: 1.7814 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 16/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.7261 - accuracy: 0.5893 - precision: 0.5893 - val_loss: 1.9033 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 17/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.7260 - accuracy: 0.5638 - precision: 0.5638 - val_loss: 1.4735 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 18/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.7438 - accuracy: 0.5434 - precision: 0.5434 - val_loss: 0.6924 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 19/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.7667 - accuracy: 0.5689 - precision: 0.5689 - val_loss: 0.8724 - val_accuracy: 0.5000 - val_precision: 0.5000
# Epoch 20/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6939 - accuracy: 0.5893 - precision: 0.5893 - val_loss: 0.6931 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 21/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6685 - accuracy: 0.5995 - precision: 0.5995 - val_loss: 0.6965 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 22/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6962 - accuracy: 0.6173 - precision: 0.6173 - val_loss: 0.6964 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 23/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6742 - accuracy: 0.6097 - precision: 0.6097 - val_loss: 0.7007 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 24/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6915 - accuracy: 0.6250 - precision: 0.6250 - val_loss: 0.7034 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 25/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6970 - accuracy: 0.5740 - precision: 0.5740 - val_loss: 0.7040 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 26/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6698 - accuracy: 0.6046 - precision: 0.6046 - val_loss: 0.7088 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 27/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6814 - accuracy: 0.5969 - precision: 0.5969 - val_loss: 0.7104 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 28/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6685 - accuracy: 0.6020 - precision: 0.6020 - val_loss: 0.7122 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 29/50
# 40/40 [==============================] - 8s 191ms/step - loss: 0.6753 - accuracy: 0.6097 - precision: 0.6097 - val_loss: 0.7172 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 30/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6614 - accuracy: 0.6250 - precision: 0.6250 - val_loss: 0.7293 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 31/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6715 - accuracy: 0.5995 - precision: 0.5995 - val_loss: 0.7352 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 32/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6765 - accuracy: 0.6199 - precision: 0.6199 - val_loss: 0.7097 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 33/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6707 - accuracy: 0.6097 - precision: 0.6097 - val_loss: 0.7258 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 34/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6632 - accuracy: 0.6224 - precision: 0.6224 - val_loss: 0.7138 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 35/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6583 - accuracy: 0.6301 - precision: 0.6301 - val_loss: 0.7135 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 36/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6583 - accuracy: 0.6224 - precision: 0.6224 - val_loss: 0.7065 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 37/50
# 40/40 [==============================] - 8s 191ms/step - loss: 0.6677 - accuracy: 0.6199 - precision: 0.6199 - val_loss: 0.7419 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 38/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6695 - accuracy: 0.6046 - precision: 0.6046 - val_loss: 0.7161 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 39/50
# 40/40 [==============================] - 8s 191ms/step - loss: 0.6611 - accuracy: 0.6097 - precision: 0.6097 - val_loss: 0.7735 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 40/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6601 - accuracy: 0.6122 - precision: 0.6122 - val_loss: 0.7086 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 41/50
# 40/40 [==============================] - 8s 192ms/step - loss: 0.6755 - accuracy: 0.6122 - precision: 0.6122 - val_loss: 0.7061 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 42/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6708 - accuracy: 0.6250 - precision: 0.6250 - val_loss: 0.7193 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 43/50
# 40/40 [==============================] - 8s 192ms/step - loss: 0.6726 - accuracy: 0.6173 - precision: 0.6173 - val_loss: 0.8428 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 44/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6548 - accuracy: 0.6173 - precision: 0.6173 - val_loss: 0.9141 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 45/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6645 - accuracy: 0.6224 - precision: 0.6224 - val_loss: 0.6920 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 46/50
# 40/40 [==============================] - 8s 191ms/step - loss: 0.6664 - accuracy: 0.6097 - precision: 0.6097 - val_loss: 0.6978 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 47/50
# 40/40 [==============================] - 8s 190ms/step - loss: 0.6630 - accuracy: 0.6122 - precision: 0.6122 - val_loss: 0.6989 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 48/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6652 - accuracy: 0.6046 - precision: 0.6046 - val_loss: 1.3225 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 49/50
# 40/40 [==============================] - 8s 189ms/step - loss: 0.6700 - accuracy: 0.6199 - precision: 0.6199 - val_loss: 1.5482 - val_accuracy: 0.5417 - val_precision: 0.5417
# Epoch 50/50
# 40/40 [==============================] - 8s 188ms/step - loss: 0.6676 - accuracy: 0.6199 - precision: 0.6199 - val_loss: 1.1978 - val_accuracy: 0.5417 - val_precision: 0.5417

# %%
precision = result.history['precision']
loss = result.history['loss']
accuracy = result.history['accuracy']
val_precision = result.history['val_precision']
val_loss = result.history['val_loss']
val_accuracy = result.history['val_accuracy']
epochs = range(len(accuracy))

plt.plot(epochs, precision, 'g', label='Training Precision')
plt.plot(epochs, val_precision, 'r', label='Validation Precision')
plt.title('Train vs Val: Precision')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Train vs Val: Loss')
plt.legend()
plt.figure()
plt.plot(epochs, accuracy, 'g', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Train vs Val: Accuracy')
plt.legend()
plt.figure()
plt.show()
